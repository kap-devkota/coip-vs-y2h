# %%
import pandas as pd
from Bio import SeqIO

# %%
dfintact = pd.read_csv("../data/networks/fly/fly_intact.tsv", sep = "\t")
dfB = dfintact.head().T
dfB.insert(0, "iden", range(len(dfB)))
dfB
# Out:
#                                      iden  \
# #ID(s) interactor A                     0
# ID(s) interactor B                      1
# Alt. ID(s) interactor A                 2
# Alt. ID(s) interactor B                 3
# Alias(es) interactor A                  4
# Alias(es) interactor B                  5
# Interaction detection method(s)         6
# Publication 1st author(s)               7
# Publication Identifier(s)               8
# Taxid interactor A                      9
# Taxid interactor B                     10
# Interaction type(s)                    11
# Source database(s)                     12
# Interaction identifier(s)              13
# Confidence value(s)                    14
# Expansion method(s)                    15
# Biological role(s) interactor A        16
# Biological role(s) interactor B        17
# Experimental role(s) interactor A      18
# Experimental role(s) interactor B      19
# Type(s) interactor A                   20
# Type(s) interactor B                   21
# Xref(s) interactor A                   22
# Xref(s) interactor B                   23
# Interaction Xref(s)                    24
# Annotation(s) interactor A             25
# Annotation(s) interactor B             26
# Interaction annotation(s)              27
# Host organism(s)                       28
# Interaction parameter(s)               29
# Creation date                          30
# Update date                            31
# Checksum(s) interactor A               32
# Checksum(s) interactor B               33
# Interaction Checksum(s)                34
# Negative                               35
# Feature(s) interactor A                36
# Feature(s) interactor B                37
# Stoichiometry(s) interactor A          38
# Stoichiometry(s) interactor B          39
# Identification method participant A    40
# Identification method participant B    41
#
#                                                                                      0  \
# #ID(s) interactor A                                                   uniprotkb:P16371
# ID(s) interactor B                                                    uniprotkb:P14003
# Alt. ID(s) interactor A              intact:EBI-153866|intact:EBI-1639108|uniprotkb...
# Alt. ID(s) interactor B              intact:EBI-123011|intact:EBI-1639662|uniprotkb...
# Alias(es) interactor A               psi-mi:grou_drome(display_long)|uniprotkb:gro(...
# Alias(es) interactor B               psi-mi:hair_drome(display_long)|uniprotkb:CG64...
# Interaction detection method(s)                            psi-mi:"MI:0096"(pull down)
# Publication 1st author(s)                                          Zhang et al. (1999)
# Publication Identifier(s)                             mint:MINT-6548485|pubmed:9892668
# Taxid interactor A                   taxid:7227(drome)|taxid:7227("Drosophila melan...
# Taxid interactor B                   taxid:7227(drome)|taxid:7227("Drosophila melan...
# Interaction type(s)                               psi-mi:"MI:0407"(direct interaction)
# Source database(s)                                              psi-mi:"MI:0471"(MINT)
# Interaction identifier(s)                           intact:EBI-8667903|mint:MINT-14789
# Confidence value(s)                                                intact-miscore:0.82
# Expansion method(s)                                                                  -
# Biological role(s) interactor A                     psi-mi:"MI:0499"(unspecified role)
# Biological role(s) interactor B                     psi-mi:"MI:0499"(unspecified role)
# Experimental role(s) interactor A                               psi-mi:"MI:0496"(bait)
# Experimental role(s) interactor B                               psi-mi:"MI:0498"(prey)
# Type(s) interactor A                                         psi-mi:"MI:0326"(protein)
# Type(s) interactor B                                         psi-mi:"MI:0326"(protein)
# Xref(s) interactor A                 refseq:NP_001189293.1|refseq:NP_524514.2|refse...
# Xref(s) interactor B                 refseq:NP_001014577.1|refseq:NP_523977.2|flyba...
# Interaction Xref(s)                                                                  -
# Annotation(s) interactor A                                comment:"Stoichiometry: 1.0"
# Annotation(s) interactor B                                comment:"Stoichiometry: 1.0"
# Interaction annotation(s)                                                 comment:mint
# Host organism(s)                                 taxid:-1(in vitro)|taxid:-1(In vitro)
# Interaction parameter(s)                                                             -
# Creation date                                                               2001/02/25
# Update date                                                                 2014/10/16
# Checksum(s) interactor A                         rogid:oSo29NrCWIeCi2OMusohCk64uiw7227
# Checksum(s) interactor B                         rogid:bO023bTsk72HhqvmgSjLEIotrDw7227
# Interaction Checksum(s)              intact-crc:43555B21FFEEAE7A|rigid:FHdrglr3JteK...
# Negative                                                                         False
# Feature(s) interactor A                               glutathione s tranferase tag:?-?
# Feature(s) interactor B              binding-associated region:334-337(MINT-1542898...
# Stoichiometry(s) interactor A                                                        -
# Stoichiometry(s) interactor B                                                        -
# Identification method participant A  psi-mi:"MI:0821"(molecular weight estimation b...
# Identification method participant B  psi-mi:"MI:0821"(molecular weight estimation b...
#
#                                                                                      1  \
# #ID(s) interactor A                                                   uniprotkb:O46036
# ID(s) interactor B                                                    uniprotkb:P14003
# Alt. ID(s) interactor A              intact:EBI-159330|uniprotkb:O61283|uniprotkb:Q...
# Alt. ID(s) interactor B              intact:EBI-123011|intact:EBI-1639662|uniprotkb...
# Alias(es) interactor A               psi-mi:ctbp_drome(display_long)|uniprotkb:CtBP...
# Alias(es) interactor B               psi-mi:hair_drome(display_long)|uniprotkb:CG64...
# Interaction detection method(s)                            psi-mi:"MI:0096"(pull down)
# Publication 1st author(s)                                          Zhang et al. (1999)
# Publication Identifier(s)                             mint:MINT-6548485|pubmed:9892668
# Taxid interactor A                   taxid:7227(drome)|taxid:7227("Drosophila melan...
# Taxid interactor B                   taxid:7227(drome)|taxid:7227("Drosophila melan...
# Interaction type(s)                               psi-mi:"MI:0407"(direct interaction)
# Source database(s)                                              psi-mi:"MI:0471"(MINT)
# Interaction identifier(s)                           intact:EBI-8716150|mint:MINT-14789
# Confidence value(s)                                                intact-miscore:0.79
# Expansion method(s)                                                                  -
# Biological role(s) interactor A                     psi-mi:"MI:0499"(unspecified role)
# Biological role(s) interactor B                     psi-mi:"MI:0499"(unspecified role)
# Experimental role(s) interactor A                               psi-mi:"MI:0496"(bait)
# Experimental role(s) interactor B                               psi-mi:"MI:0498"(prey)
# Type(s) interactor A                                         psi-mi:"MI:0326"(protein)
# Type(s) interactor B                                         psi-mi:"MI:0326"(protein)
# Xref(s) interactor A                 refseq:NP_001014617.1|refseq:NP_524336.2|refse...
# Xref(s) interactor B                 refseq:NP_001014577.1|refseq:NP_523977.2|flyba...
# Interaction Xref(s)                                                                  -
# Annotation(s) interactor A                                                           -
# Annotation(s) interactor B                                comment:"Stoichiometry: 1.0"
# Interaction annotation(s)                                                 comment:mint
# Host organism(s)                                 taxid:-1(in vitro)|taxid:-1(In vitro)
# Interaction parameter(s)                                                             -
# Creation date                                                               2001/02/25
# Update date                                                                 2014/10/16
# Checksum(s) interactor A                         rogid:hbMeldNlirFwVr+5QX9bGiPqZ1w7227
# Checksum(s) interactor B                         rogid:bO023bTsk72HhqvmgSjLEIotrDw7227
# Interaction Checksum(s)              intact-crc:E548EEFF3BEC0246|rigid:6SxefJVI+l+g...
# Negative                                                                         False
# Feature(s) interactor A                               glutathione s tranferase tag:?-?
# Feature(s) interactor B              35s radiolabel:?-?|binding-associated region:3...
# Stoichiometry(s) interactor A                                                        -
# Stoichiometry(s) interactor B                                                        -
# Identification method participant A  psi-mi:"MI:0821"(molecular weight estimation b...
# Identification method participant B  psi-mi:"MI:0821"(molecular weight estimation b...
#
#                                                                                      2  \
# #ID(s) interactor A                                                   uniprotkb:P13098
# ID(s) interactor B                                                    uniprotkb:P08181
# Alt. ID(s) interactor A              intact:EBI-185388|intact:EBI-1639218|uniprotkb...
# Alt. ID(s) interactor B              intact:EBI-93115|uniprotkb:Q0E8B4|uniprotkb:Q9...
# Alias(es) interactor A               psi-mi:esm8_drome(display_long)|uniprotkb:"E(s...
# Alias(es) interactor B               psi-mi:csk2a_drome(display_long)|uniprotkb:CkI...
# Interaction detection method(s)                            psi-mi:"MI:0096"(pull down)
# Publication 1st author(s)                                          Trott et al. (2001)
# Publication Identifier(s)                            pubmed:11208814|mint:MINT-5213561
# Taxid interactor A                   taxid:7227(drome)|taxid:7227("Drosophila melan...
# Taxid interactor B                   taxid:7227(drome)|taxid:7227("Drosophila melan...
# Interaction type(s)                               psi-mi:"MI:0407"(direct interaction)
# Source database(s)                                              psi-mi:"MI:0471"(MINT)
# Interaction identifier(s)                           intact:EBI-7773762|mint:MINT-17272
# Confidence value(s)                                                intact-miscore:0.60
# Expansion method(s)                                                                  -
# Biological role(s) interactor A                     psi-mi:"MI:0499"(unspecified role)
# Biological role(s) interactor B                     psi-mi:"MI:0499"(unspecified role)
# Experimental role(s) interactor A                               psi-mi:"MI:0498"(prey)
# Experimental role(s) interactor B                               psi-mi:"MI:0496"(bait)
# Type(s) interactor A                                         psi-mi:"MI:0326"(protein)
# Type(s) interactor B                                         psi-mi:"MI:0326"(protein)
# Xref(s) interactor A                 refseq:NP_524513.1|flybase:FBgn0000591|dip:DIP...
# Xref(s) interactor B                 go:"GO:0005956"(protein kinase CK2 complex)|go...
# Interaction Xref(s)                                                                  -
# Annotation(s) interactor A                                comment:"Stoichiometry: 1.0"
# Annotation(s) interactor B                                comment:"Stoichiometry: 1.0"
# Interaction annotation(s)            comment:CKII binds and phosphorylaes m8 on Ser...
# Host organism(s)                                 taxid:-1(in vitro)|taxid:-1(In vitro)
# Interaction parameter(s)                                                             -
# Creation date                                                               2001/06/04
# Update date                                                                 2014/10/16
# Checksum(s) interactor A                         rogid:Ytd8Ad4FJAfx25V7mHNi9e+F0pw7227
# Checksum(s) interactor B                         rogid:0wrL1LjHFiPEQg3UxDl917ya/qg7227
# Interaction Checksum(s)              intact-crc:828483A1856961E2|rigid:jm4iqqbCe8IB...
# Negative                                                                         False
# Feature(s) interactor A                                                              -
# Feature(s) interactor B                                                              -
# Stoichiometry(s) interactor A                                                        -
# Stoichiometry(s) interactor B                                                        -
# Identification method participant A        psi-mi:"MI:0396"(predetermined participant)
# Identification method participant B        psi-mi:"MI:0396"(predetermined participant)
#
#                                                                                      3  \
# #ID(s) interactor A                                                   uniprotkb:P08181
# ID(s) interactor B                                                    uniprotkb:P13097
# Alt. ID(s) interactor A              intact:EBI-93115|uniprotkb:Q0E8B4|uniprotkb:Q9...
# Alt. ID(s) interactor B              intact:EBI-178179|intact:EBI-1639161|uniprotkb...
# Alias(es) interactor A               psi-mi:csk2a_drome(display_long)|uniprotkb:CkI...
# Alias(es) interactor B               psi-mi:esm7_drome(display_long)|uniprotkb:"E(s...
# Interaction detection method(s)                           psi-mi:"MI:0018"(two hybrid)
# Publication 1st author(s)                                          Trott et al. (2001)
# Publication Identifier(s)                            pubmed:11208814|mint:MINT-5213561
# Taxid interactor A                   taxid:7227(drome)|taxid:7227("Drosophila melan...
# Taxid interactor B                   taxid:7227(drome)|taxid:7227("Drosophila melan...
# Interaction type(s)                             psi-mi:"MI:0915"(physical association)
# Source database(s)                                              psi-mi:"MI:0471"(MINT)
# Interaction identifier(s)                           intact:EBI-7773813|mint:MINT-13730
# Confidence value(s)                                                intact-miscore:0.50
# Expansion method(s)                                                                  -
# Biological role(s) interactor A                     psi-mi:"MI:0499"(unspecified role)
# Biological role(s) interactor B                     psi-mi:"MI:0499"(unspecified role)
# Experimental role(s) interactor A                               psi-mi:"MI:0496"(bait)
# Experimental role(s) interactor B                               psi-mi:"MI:0498"(prey)
# Type(s) interactor A                                         psi-mi:"MI:0326"(protein)
# Type(s) interactor B                                         psi-mi:"MI:0326"(protein)
# Xref(s) interactor A                 go:"GO:0005956"(protein kinase CK2 complex)|go...
# Xref(s) interactor B                 refseq:NP_536753.1|flybase:FBgn0002633|dip:DIP...
# Interaction Xref(s)                                                                  -
# Annotation(s) interactor A                                comment:"Stoichiometry: 1.0"
# Annotation(s) interactor B                                comment:"Stoichiometry: 1.0"
# Interaction annotation(s)                                                 comment:mint
# Host organism(s)                                   taxid:-4(in vivo)|taxid:-4(in vivo)
# Interaction parameter(s)                                                             -
# Creation date                                                               2001/06/04
# Update date                                                                 2014/10/16
# Checksum(s) interactor A                         rogid:0wrL1LjHFiPEQg3UxDl917ya/qg7227
# Checksum(s) interactor B                         rogid:ko+76awzLWRJNBn06B3PQZWBhf47227
# Interaction Checksum(s)              intact-crc:39703168685D7B5F|rigid:TlF6WY6a0g+g...
# Negative                                                                         False
# Feature(s) interactor A                                           tag:?-?(MINT-468436)
# Feature(s) interactor B                                           tag:?-?(MINT-468442)
# Stoichiometry(s) interactor A                                                        -
# Stoichiometry(s) interactor B                                                        -
# Identification method participant A  psi-mi:"MI:0078"(nucleotide sequence identific...
# Identification method participant B  psi-mi:"MI:0078"(nucleotide sequence identific...
#
#                                                                                      4
# #ID(s) interactor A                                                   uniprotkb:P13096
# ID(s) interactor B                                                    uniprotkb:P08181
# Alt. ID(s) interactor A              intact:EBI-104760|uniprotkb:Q9VBI8|intact:EBI-...
# Alt. ID(s) interactor B              intact:EBI-93115|uniprotkb:Q0E8B4|uniprotkb:Q9...
# Alias(es) interactor A               psi-mi:esm5_drome(display_long)|uniprotkb:"E(s...
# Alias(es) interactor B               psi-mi:csk2a_drome(display_long)|uniprotkb:CkI...
# Interaction detection method(s)                           psi-mi:"MI:0018"(two hybrid)
# Publication 1st author(s)                                          Trott et al. (2001)
# Publication Identifier(s)                            pubmed:11208814|mint:MINT-5213561
# Taxid interactor A                   taxid:7227(drome)|taxid:7227("Drosophila melan...
# Taxid interactor B                   taxid:7227(drome)|taxid:7227("Drosophila melan...
# Interaction type(s)                             psi-mi:"MI:0915"(physical association)
# Source database(s)                                              psi-mi:"MI:0471"(MINT)
# Interaction identifier(s)                           intact:EBI-7773861|mint:MINT-16019
# Confidence value(s)                                                intact-miscore:0.37
# Expansion method(s)                                                                  -
# Biological role(s) interactor A                     psi-mi:"MI:0499"(unspecified role)
# Biological role(s) interactor B                     psi-mi:"MI:0499"(unspecified role)
# Experimental role(s) interactor A                               psi-mi:"MI:0498"(prey)
# Experimental role(s) interactor B                               psi-mi:"MI:0496"(bait)
# Type(s) interactor A                                         psi-mi:"MI:0326"(protein)
# Type(s) interactor B                                         psi-mi:"MI:0326"(protein)
# Xref(s) interactor A                 refseq:NP_524511.1|flybase:FBgn0002631|ensembl...
# Xref(s) interactor B                 go:"GO:0005956"(protein kinase CK2 complex)|go...
# Interaction Xref(s)                                                                  -
# Annotation(s) interactor A                                comment:"Stoichiometry: 1.0"
# Annotation(s) interactor B                                comment:"Stoichiometry: 1.0"
# Interaction annotation(s)                                                 comment:mint
# Host organism(s)                                   taxid:-4(in vivo)|taxid:-4(in vivo)
# Interaction parameter(s)                                                             -
# Creation date                                                               2001/06/04
# Update date                                                                 2014/10/16
# Checksum(s) interactor A                         rogid:UP+P9xXX98OeDVDxA1ePXRWmaXs7227
# Checksum(s) interactor B                         rogid:0wrL1LjHFiPEQg3UxDl917ya/qg7227
# Interaction Checksum(s)              intact-crc:69507FC6E4E8110C|rigid:yBXkcyljNn1W...
# Negative                                                                         False
# Feature(s) interactor A                                           tag:?-?(MINT-468472)
# Feature(s) interactor B                                           tag:?-?(MINT-468466)
# Stoichiometry(s) interactor A                                                        -
# Stoichiometry(s) interactor B                                                        -
# Identification method participant A  psi-mi:"MI:0078"(nucleotide sequence identific...
# Identification method participant B  psi-mi:"MI:0078"(nucleotide sequence identific...

# %%
dfintact.loc[dfintact.iloc[:, 6].isin(coipmethods), :].iloc[:, 14].apply(lambda s: 0 if s == "-" else float(s.split(":")[-1])).hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
dfintact.loc[dfintact.iloc[:, 6].isin(y2hmethods), :].iloc[:, 14].apply(lambda s: 0 if s == "-" else float(s.split(":")[-1])).hist(bins = 20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## COIP CONF          = 0
# ## Y2H CONF Threshold = 0.45

# %%
coipconf = 0
y2hconf  = 0.45

# %%
methods = list(set(methods[:, 0]))
list(enumerate(methods))
# Out:
# [(0, 'psi-mi:"MI:0053"(fluorescence polarization spectroscopy)'),
#  (1, 'psi-mi:"MI:0107"(surface plasmon resonance)'),
#  (2, 'psi-mi:"MI:0663"(confocal microscopy)'),
#  (3, 'psi-mi:"MI:0017"(classical fluorescence spectroscopy)'),
#  (4, 'psi-mi:"MI:0415"(enzymatic study)'),
#  (5, 'psi-mi:"MI:0069"(mass spectrometry studies of complexes)'),
#  (6, 'psi-mi:"MI:0067"(light scattering)'),
#  (7, 'psi-mi:"MI:0588"(three hybrid)'),
#  (8, 'psi-mi:"MI:0276"(blue native page)'),
#  (9, 'psi-mi:"MI:0411"(enzyme linked immunosorbent assay)'),
#  (10, 'psi-mi:"MI:0049"(filter binding)'),
#  (11, 'psi-mi:"MI:0428"(imaging technique)'),
#  (12, 'psi-mi:"MI:0084"(phage display)'),
#  (13, 'psi-mi:"MI:0399"(two hybrid fragment pooling approach)'),
#  (14, 'psi-mi:"MI:0010"(beta galactosidase complementation)'),
#  (15, 'psi-mi:"MI:0434"(phosphatase assay)'),
#  (16, 'psi-mi:"MI:0104"(static light scattering)'),
#  (17, 'psi-mi:"MI:0006"(anti bait coimmunoprecipitation)'),
#  (18, 'psi-mi:"MI:0096"(pull down)'),
#  (19, 'psi-mi:"MI:0030"(cross-linking study)'),
#  (20, 'psi-mi:"MI:0226"(ion exchange chromatography)'),
#  (21, 'psi-mi:"MI:0963"(interactome parallel affinity capture)'),
#  (22, 'psi-mi:"MI:0232"(transcriptional complementation assay)'),
#  (23, 'psi-mi:"MI:0946"(miniaturized immunoprecipitation)'),
#  (24, 'psi-mi:"MI:0047"(far western blotting)'),
#  (25, 'psi-mi:"MI:0402"(chromatin immunoprecipitation assay)'),
#  (26, 'psi-mi:"MI:0416"(fluorescence microscopy)'),
#  (27, 'psi-mi:"MI:0004"(affinity chromatography technology)'),
#  (28, 'psi-mi:"MI:0808"(comigration in sds page)'),
#  (29, 'psi-mi:"MI:0413"(electrophoretic mobility shift assay)'),
#  (30, 'psi-mi:"MI:0404"(comigration in non denaturing gel electrophoresis)'),
#  (31, 'psi-mi:"MI:0081"(peptide array)'),
#  (32, 'psi-mi:"MI:0966"(ultraviolet-visible spectroscopy)'),
#  (33, 'psi-mi:"MI:0888"(small angle neutron scattering)'),
#  (34, 'psi-mi:"MI:0423"(in-gel kinase assay)'),
#  (35, 'psi-mi:"MI:0038"(dynamic light scattering)'),
#  (36, 'psi-mi:"MI:0400"(affinity technology)'),
#  (37, 'psi-mi:"MI:0949"(gdp/gtp exchange assay)'),
#  (38, 'psi-mi:"MI:0397"(two hybrid array)'),
#  (39, 'psi-mi:"MI:0892"(solid phase assay)'),
#  (40, 'psi-mi:"MI:0729"(luminescence based mammalian interactome mapping)'),
#  (41, 'psi-mi:"MI:0435"(protease assay)'),
#  (42, 'psi-mi:"MI:0027"(cosedimentation)'),
#  (43, 'psi-mi:"MI:1247"(microscale thermophoresis)'),
#  (44, 'psi-mi:"MI:0676"(tandem affinity purification)'),
#  (45, 'psi-mi:"MI:0018"(two hybrid)'),
#  (46, 'psi-mi:"MI:0091"(chromatography technology)'),
#  (47, 'psi-mi:"MI:0410"(3D electron microscopy)'),
#  (48, 'psi-mi:"MI:0406"(deacetylase assay)'),
#  (49, 'psi-mi:"MI:0066"(lambda phage display)'),
#  (50, 'psi-mi:"MI:0889"(acetylase assay)'),
#  (51, 'psi-mi:"MI:0424"(protein kinase assay)'),
#  (52, 'psi-mi:"MI:1112"(two hybrid prey pooling approach)'),
#  (53, 'psi-mi:"MI:0051"(fluorescence technology)'),
#  (54, 'psi-mi:"MI:0401"(biochemical)'),
#  (55, 'psi-mi:"MI:0065"(isothermal titration calorimetry)'),
#  (56, 'psi-mi:"MI:0809"(bimolecular fluorescence complementation)'),
#  (57, 'psi-mi:"MI:0114"(x-ray crystallography)'),
#  (58, 'psi-mi:"MI:0007"(anti tag coimmunoprecipitation)'),
#  (59, 'psi-mi:"MI:0055"(fluorescent resonance energy transfer)'),
#  (60, 'psi-mi:"MI:0071"(molecular sieving)'),
#  (61, 'psi-mi:"MI:0040"(electron microscopy)'),
#  (62, 'psi-mi:"MI:0813"(proximity ligation assay)'),
#  (63, 'psi-mi:"MI:0029"(cosedimentation through density gradient)'),
#  (64, 'psi-mi:"MI:0019"(coimmunoprecipitation)'),
#  (65, 'psi-mi:"MI:0077"(nuclear magnetic resonance)'),
#  (66, 'psi-mi:"MI:0045"(experimental interaction detection)'),
#  (67, 'psi-mi:"MI:0020"(transmission electron microscopy)'),
#  (68, 'psi-mi:"MI:0826"(x ray scattering)'),
#  (69, 'psi-mi:"MI:0028"(cosedimentation in solution)')]

# %%
method_count = dfintact.iloc[:, [6]].value_counts().sort_values()
method_count.tail(20)
# Out:
# Interaction detection method(s)
# psi-mi:"MI:0424"(protein kinase assay)                           46
# psi-mi:"MI:0055"(fluorescent resonance energy transfer)          53
# psi-mi:"MI:0809"(bimolecular fluorescence complementation)       56
# psi-mi:"MI:0114"(x-ray crystallography)                          58
# psi-mi:"MI:0416"(fluorescence microscopy)                        80
# psi-mi:"MI:0676"(tandem affinity purification)                   86
# psi-mi:"MI:0019"(coimmunoprecipitation)                          87
# psi-mi:"MI:0402"(chromatin immunoprecipitation assay)            93
# psi-mi:"MI:0071"(molecular sieving)                             106
# psi-mi:"MI:0892"(solid phase assay)                             193
# psi-mi:"MI:0029"(cosedimentation through density gradient)      296
# psi-mi:"MI:0006"(anti bait coimmunoprecipitation)               554
# psi-mi:"MI:0963"(interactome parallel affinity capture)         777
# psi-mi:"MI:0045"(experimental interaction detection)            838
# psi-mi:"MI:0399"(two hybrid fragment pooling approach)         1802
# psi-mi:"MI:0096"(pull down)                                    8052
# psi-mi:"MI:0007"(anti tag coimmunoprecipitation)               8432
# psi-mi:"MI:1112"(two hybrid prey pooling approach)             9075
# psi-mi:"MI:0397"(two hybrid array)                            11930
# psi-mi:"MI:0018"(two hybrid)                                  23553
# dtype: int64

# %%
coipmethods = {methods[17], methods[25], methods[58], methods[64], methods[18], methods[44]} # pull down, #tandem affinity purification
y2hmethods  = {methods[13], methods[38], methods[45], methods[52]}

coipmethods, y2hmethods
# Out:
# ({'psi-mi:"MI:0006"(anti bait coimmunoprecipitation)',
#   'psi-mi:"MI:0007"(anti tag coimmunoprecipitation)',
#   'psi-mi:"MI:0019"(coimmunoprecipitation)',
#   'psi-mi:"MI:0096"(pull down)',
#   'psi-mi:"MI:0402"(chromatin immunoprecipitation assay)',
#   'psi-mi:"MI:0676"(tandem affinity purification)'},
#  {'psi-mi:"MI:0018"(two hybrid)',
#   'psi-mi:"MI:0397"(two hybrid array)',
#   'psi-mi:"MI:0399"(two hybrid fragment pooling approach)',
#   'psi-mi:"MI:1112"(two hybrid prey pooling approach)'})

# %%
dfy2h = dfintact[dfintact.iloc[:, 6].isin(y2hmethods)]
f_confscore = lambda s: 0 if s == "-" else float(s.split(":")[-1])
dfy2h = dfy2h.loc[ dfy2h.iloc[:,14].apply(f_confscore) > y2hconf, :].reset_index(drop=True)
dfy2h
# Out:
#       #ID(s) interactor A ID(s) interactor B  \
# 0        uniprotkb:P08181   uniprotkb:P13097
# 1        uniprotkb:P13098   uniprotkb:P08181
# 2        uniprotkb:Q24159   uniprotkb:P23573
# 3        uniprotkb:P23572   uniprotkb:P54733
# 4        uniprotkb:P23573   uniprotkb:P91654
# ...                   ...                ...
# 19111    uniprotkb:B7FNM4   uniprotkb:Q8IMF1
# 19112    uniprotkb:Q9W1Z1   uniprotkb:Q9VV10
# 19113    uniprotkb:Q9W1Z1   uniprotkb:M9PEI0
# 19114    uniprotkb:B7FNN9   uniprotkb:Q8IMF1
# 19115    uniprotkb:Q9W1Z1   uniprotkb:Q9W4Z4
#
#                                  Alt. ID(s) interactor A  \
# 0      intact:EBI-93115|uniprotkb:Q0E8B4|uniprotkb:Q9...
# 1      intact:EBI-185388|intact:EBI-1639218|uniprotkb...
# 2                   intact:EBI-455799|intact:EBI-1629390
# 3      intact:EBI-108689|intact:EBI-1627558|uniprotkb...
# 4      intact:EBI-95916|intact:EBI-1627637|uniprotkb:...
# ...                                                  ...
# 19111     intact:EBI-26710187|ensemblmetazoa:FBpp0072925
# 19112       intact:EBI-108298|ensemblmetazoa:FBpp0071804
# 19113       intact:EBI-108298|ensemblmetazoa:FBpp0071804
# 19114     intact:EBI-26701979|ensemblmetazoa:FBpp0072923
# 19115       intact:EBI-108298|ensemblmetazoa:FBpp0071804
#
#                                  Alt. ID(s) interactor B  \
# 0      intact:EBI-178179|intact:EBI-1639161|uniprotkb...
# 1      intact:EBI-93115|uniprotkb:Q0E8B4|uniprotkb:Q9...
# 2      intact:EBI-95916|intact:EBI-1627637|uniprotkb:...
# 3      intact:EBI-203549|intact:EBI-1628120|uniprotkb...
# 4                   intact:EBI-868936|intact:EBI-1627645
# ...                                                  ...
# 19111  intact:EBI-26702095|ensemblmetazoa:FBpp0085303...
# 19112  intact:EBI-105782|uniprotkb:A8WHC0|ensemblmeta...
# 19113     intact:EBI-26700375|ensemblmetazoa:FBpp0303120
# 19114  intact:EBI-26702095|ensemblmetazoa:FBpp0085303...
# 19115  intact:EBI-143792|uniprotkb:C4XVH4|ensemblmeta...
#
#                                   Alias(es) interactor A  \
# 0      psi-mi:csk2a_drome(display_long)|uniprotkb:CkI...
# 1      psi-mi:esm8_drome(display_long)|uniprotkb:"E(s...
# 2      psi-mi:q24159_drome(display_long)|uniprotkb:Cy...
# 3      psi-mi:cdk1_drome(display_long)|uniprotkb:Cdk1...
# 4      psi-mi:cdk2_drome(display_long)|uniprotkb:Cdk2...
# ...                                                  ...
# 19111  psi-mi:b7fnm4_drome(display_long)|uniprotkb:dr...
# 19112  psi-mi:q9w1z1_drome(display_long)|uniprotkb:Dm...
# 19113  psi-mi:q9w1z1_drome(display_long)|uniprotkb:Dm...
# 19114  psi-mi:b7fnn9_drome(display_long)|uniprotkb:dr...
# 19115  psi-mi:q9w1z1_drome(display_long)|uniprotkb:Dm...
#
#                                   Alias(es) interactor B  \
# 0      psi-mi:esm7_drome(display_long)|uniprotkb:"E(s...
# 1      psi-mi:csk2a_drome(display_long)|uniprotkb:CkI...
# 2      psi-mi:cdk2_drome(display_long)|uniprotkb:Cdk2...
# 3      psi-mi:ccne_drome(display_long)|uniprotkb:CycE...
# 4      psi-mi:p91654_drome(display_long)|uniprotkb:da...
# ...                                                  ...
# 19111  psi-mi:q8imf1_drome(display_long)|uniprotkb:Dm...
# 19112  psi-mi:q9vv10_drome(display_long)|uniprotkb:Dm...
# 19113  psi-mi:m9pei0_drome(display_long)|uniprotkb:Dm...
# 19114  psi-mi:q8imf1_drome(display_long)|uniprotkb:Dm...
# 19115  psi-mi:insl6_drome(display_long)|uniprotkb:Ilp...
#
#           Interaction detection method(s) Publication 1st author(s)  \
# 0            psi-mi:"MI:0018"(two hybrid)       Trott et al. (2001)
# 1            psi-mi:"MI:0018"(two hybrid)       Trott et al. (2001)
# 2            psi-mi:"MI:0018"(two hybrid)      Finley et al. (1994)
# 3            psi-mi:"MI:0018"(two hybrid)      Finley et al. (1994)
# 4            psi-mi:"MI:0018"(two hybrid)      Finley et al. (1994)
# ...                                   ...                       ...
# 19111  psi-mi:"MI:0397"(two hybrid array)       FlyBi et al. (2021)
# 19112  psi-mi:"MI:0397"(two hybrid array)       FlyBi et al. (2021)
# 19113  psi-mi:"MI:0397"(two hybrid array)       FlyBi et al. (2021)
# 19114  psi-mi:"MI:0397"(two hybrid array)       FlyBi et al. (2021)
# 19115  psi-mi:"MI:0397"(two hybrid array)       FlyBi et al. (2021)
#
#                                Publication Identifier(s)  \
# 0                      pubmed:11208814|mint:MINT-5213561
# 1                      pubmed:11208814|mint:MINT-5213561
# 2      mint:MINT-5220608|pubmed:7809159|doi:10.1073/p...
# 3      mint:MINT-5220608|pubmed:7809159|doi:10.1073/p...
# 4      mint:MINT-5220608|pubmed:7809159|doi:10.1073/p...
# ...                                                  ...
# 19111                pubmed:unassigned2874|imex:IM-28761
# 19112                pubmed:unassigned2874|imex:IM-28761
# 19113                pubmed:unassigned2874|imex:IM-28761
# 19114                pubmed:unassigned2874|imex:IM-28761
# 19115                pubmed:unassigned2874|imex:IM-28761
#
#                                       Taxid interactor A  ...  \
# 0      taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 1      taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 2      taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 3      taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 4      taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# ...                                                  ...  ...
# 19111  taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 19112  taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 19113  taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 19114  taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 19115  taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
#
#                     Checksum(s) interactor A  \
# 0      rogid:0wrL1LjHFiPEQg3UxDl917ya/qg7227
# 1      rogid:Ytd8Ad4FJAfx25V7mHNi9e+F0pw7227
# 2      rogid:v0+u1HylNkW8beHZZmGfAIjkczo7227
# 3      rogid:WK4kxTRU/nlh6/LCeihCplHOZ2o7227
# 4      rogid:PFQ6DWcVE9kINQT+XsO0c7ROMLc7227
# ...                                      ...
# 19111  rogid:GUZ1PnqToQZ53uQ0klnb1AmgR5A7227
# 19112  rogid:YXcbfHJXFdRx0jFUnZ7SaAYEHyI7227
# 19113  rogid:YXcbfHJXFdRx0jFUnZ7SaAYEHyI7227
# 19114  rogid:hrRXo69AtyD9T5LzLXgw0uTUfJI7227
# 19115  rogid:YXcbfHJXFdRx0jFUnZ7SaAYEHyI7227
#
#                     Checksum(s) interactor B  \
# 0      rogid:ko+76awzLWRJNBn06B3PQZWBhf47227
# 1      rogid:0wrL1LjHFiPEQg3UxDl917ya/qg7227
# 2      rogid:PFQ6DWcVE9kINQT+XsO0c7ROMLc7227
# 3      rogid:AwK/vwBDPgICbmeNxOxrcsj5kiQ7227
# 4      rogid:ntkvuc9a0N4KShJCJrbHYgpwBS47227
# ...                                      ...
# 19111  rogid:YruPatLkRte5w69v27aCpH7tQZE7227
# 19112  rogid:fZEzOTnoJElah0ux2RtCgcaoVLo7227
# 19113  rogid:ojsyI+Bp1As3edVzqa0OVU4EKzw7227
# 19114  rogid:YruPatLkRte5w69v27aCpH7tQZE7227
# 19115  rogid:M4XsjaajAlgT/NrpPGL2Od7QobY7227
#
#                                  Interaction Checksum(s) Negative  \
# 0      intact-crc:39703168685D7B5F|rigid:TlF6WY6a0g+g...    False
# 1      intact-crc:E5AD7D196D835D58|rigid:jm4iqqbCe8IB...    False
# 2      intact-crc:24BD23B4482F282B|rigid:CLKkZwct3U4X...    False
# 3      intact-crc:137AAF47A1AE1762|rigid:pvYn9pnjx9q/...    False
# 4      intact-crc:F4FEA94C09D2AEFA|rigid:psuadseCHR47...    False
# ...                                                  ...      ...
# 19111                  rigid:MUfFznmUj5o01n2rm9pzxpk5p0I    False
# 19112                  rigid:Xy3P7/btcf6oRaxc3u13Fu9joHo    False
# 19113                  rigid:9wulPO8TPzkH+9UzsgM+vzqV9SI    False
# 19114                  rigid:uov5DBovdk9dK+TbFO+ioKwmtdU    False
# 19115                  rigid:MzQ41XInqrJ2L+Qu6sgooXCBz40    False
#
#               Feature(s) interactor A          Feature(s) interactor B  \
# 0                tag:?-?(MINT-468436)             tag:?-?(MINT-468442)
# 1                tag:?-?(MINT-468457)             tag:?-?(MINT-468451)
# 2               tag:?-?(MINT-1509645)            tag:?-?(MINT-1509651)
# 3               tag:?-?(MINT-1509604)            tag:?-?(MINT-1509598)
# 4               tag:?-?(MINT-1509679)            tag:?-?(MINT-1509673)
# ...                               ...                              ...
# 19111  sufficient binding region:6-76                                -
# 19112                               -                                -
# 19113                               -  sufficient binding region:1-151
# 19114  sufficient binding region:6-75                                -
# 19115                               -                                -
#
#       Stoichiometry(s) interactor A Stoichiometry(s) interactor B  \
# 0                                 -                             -
# 1                                 -                             -
# 2                                 -                             -
# 3                                 -                             -
# 4                                 -                             -
# ...                             ...                           ...
# 19111                             -                             -
# 19112                             -                             -
# 19113                             -                             -
# 19114                             -                             -
# 19115                             -                             -
#
#                      Identification method participant A  \
# 0      psi-mi:"MI:0078"(nucleotide sequence identific...
# 1      psi-mi:"MI:0078"(nucleotide sequence identific...
# 2      psi-mi:"MI:0078"(nucleotide sequence identific...
# 3      psi-mi:"MI:0078"(nucleotide sequence identific...
# 4      psi-mi:"MI:0078"(nucleotide sequence identific...
# ...                                                  ...
# 19111  psi-mi:"MI:0078"(nucleotide sequence identific...
# 19112  psi-mi:"MI:0078"(nucleotide sequence identific...
# 19113  psi-mi:"MI:0078"(nucleotide sequence identific...
# 19114  psi-mi:"MI:0078"(nucleotide sequence identific...
# 19115  psi-mi:"MI:0078"(nucleotide sequence identific...
#
#                      Identification method participant B
# 0      psi-mi:"MI:0078"(nucleotide sequence identific...
# 1      psi-mi:"MI:0078"(nucleotide sequence identific...
# 2      psi-mi:"MI:0078"(nucleotide sequence identific...
# 3      psi-mi:"MI:0078"(nucleotide sequence identific...
# 4      psi-mi:"MI:0078"(nucleotide sequence identific...
# ...                                                  ...
# 19111  psi-mi:"MI:0078"(nucleotide sequence identific...
# 19112  psi-mi:"MI:0078"(nucleotide sequence identific...
# 19113  psi-mi:"MI:0078"(nucleotide sequence identific...
# 19114  psi-mi:"MI:0078"(nucleotide sequence identific...
# 19115  psi-mi:"MI:0078"(nucleotide sequence identific...
#
# [19116 rows x 42 columns]

# %%
dfcoip = dfintact[dfintact.iloc[:, 6].isin(coipmethods)]
dfcoip = dfcoip.loc[ dfcoip.iloc[:,14].apply(f_confscore) > coipconf, :].reset_index(drop=True)
dfcoip
# Out:
#       #ID(s) interactor A ID(s) interactor B  \
# 0        uniprotkb:P16371   uniprotkb:P14003
# 1        uniprotkb:O46036   uniprotkb:P14003
# 2        uniprotkb:P13098   uniprotkb:P08181
# 3        uniprotkb:Q7K105   uniprotkb:P08953
# 4        uniprotkb:P08953   uniprotkb:Q7K105
# ...                   ...                ...
# 17299    uniprotkb:Q9VKD7   uniprotkb:Q9VKD7
# 17300    uniprotkb:Q9VS51   uniprotkb:Q9VND8
# 17301    uniprotkb:Q9VS51   uniprotkb:Q9VND8
# 17302    uniprotkb:P28159   uniprotkb:P20226
# 17303    uniprotkb:P28159   uniprotkb:P20226
#
#                                  Alt. ID(s) interactor A  \
# 0      intact:EBI-153866|intact:EBI-1639108|uniprotkb...
# 1      intact:EBI-159330|uniprotkb:O61283|uniprotkb:Q...
# 2      intact:EBI-185388|intact:EBI-1639218|uniprotkb...
# 3      intact:EBI-129988|ensemblmetazoa:FBpp0087679|e...
# 4      intact:EBI-143610|uniprotkb:A4V3G7|uniprotkb:A...
# ...                                                  ...
# 17299  intact:EBI-9943000|ensemblmetazoa:FBpp0079900|...
# 17300  intact:EBI-180370|uniprotkb:Q8T0M3|ensemblmeta...
# 17301  intact:EBI-180370|uniprotkb:Q8T0M3|ensemblmeta...
# 17302  intact:EBI-92180|uniprotkb:Q3S1M8|uniprotkb:Q9...
# 17303  intact:EBI-92180|uniprotkb:Q3S1M8|uniprotkb:Q9...
#
#                                  Alt. ID(s) interactor B  \
# 0      intact:EBI-123011|intact:EBI-1639662|uniprotkb...
# 1      intact:EBI-123011|intact:EBI-1639662|uniprotkb...
# 2      intact:EBI-93115|uniprotkb:Q0E8B4|uniprotkb:Q9...
# 3      intact:EBI-143610|uniprotkb:A4V3G7|uniprotkb:A...
# 4      intact:EBI-129988|ensemblmetazoa:FBpp0087679|e...
# ...                                                  ...
# 17299  intact:EBI-9943000|ensemblmetazoa:FBpp0079900|...
# 17300  intact:EBI-4372932|uniprotkb:Q0KIB7|ensemblmet...
# 17301  intact:EBI-4372932|uniprotkb:Q0KIB7|ensemblmet...
# 17302  intact:EBI-355371|uniprotkb:Q16845|uniprotkb:Q...
# 17303  intact:EBI-355371|uniprotkb:Q16845|uniprotkb:Q...
#
#                                   Alias(es) interactor A  \
# 0      psi-mi:grou_drome(display_long)|uniprotkb:gro(...
# 1      psi-mi:ctbp_drome(display_long)|uniprotkb:CtBP...
# 2      psi-mi:esm8_drome(display_long)|uniprotkb:"E(s...
# 3      psi-mi:q7k105_drome(display_long)|uniprotkb:My...
# 4      psi-mi:toll_drome(display_long)|uniprotkb:Tl(g...
# ...                                                  ...
# 17299  psi-mi:zuc_drome(display_long)|uniprotkb:Prote...
# 17300  psi-mi:q9vs51_drome(display_long)|uniprotkb:Cl...
# 17301  psi-mi:q9vs51_drome(display_long)|uniprotkb:Cl...
# 17302  psi-mi:suh_drome(display_long)|uniprotkb:"Su(H...
# 17303  psi-mi:suh_drome(display_long)|uniprotkb:"Su(H...
#
#                                   Alias(es) interactor B  \
# 0      psi-mi:hair_drome(display_long)|uniprotkb:CG64...
# 1      psi-mi:hair_drome(display_long)|uniprotkb:CG64...
# 2      psi-mi:csk2a_drome(display_long)|uniprotkb:CkI...
# 3      psi-mi:toll_drome(display_long)|uniprotkb:Tl(g...
# 4      psi-mi:q7k105_drome(display_long)|uniprotkb:My...
# ...                                                  ...
# 17299  psi-mi:zuc_drome(display_long)|uniprotkb:Prote...
# 17300  psi-mi:rheb_drome(display_long)|uniprotkb:Rheb...
# 17301  psi-mi:rheb_drome(display_long)|uniprotkb:Rheb...
# 17302  psi-mi:tbp_human(display_long)|uniprotkb:TBP(g...
# 17303  psi-mi:tbp_human(display_long)|uniprotkb:TBP(g...
#
#                          Interaction detection method(s)  \
# 0                            psi-mi:"MI:0096"(pull down)
# 1                            psi-mi:"MI:0096"(pull down)
# 2                            psi-mi:"MI:0096"(pull down)
# 3                psi-mi:"MI:0019"(coimmunoprecipitation)
# 4                psi-mi:"MI:0019"(coimmunoprecipitation)
# ...                                                  ...
# 17299   psi-mi:"MI:0007"(anti tag coimmunoprecipitation)
# 17300   psi-mi:"MI:0007"(anti tag coimmunoprecipitation)
# 17301   psi-mi:"MI:0007"(anti tag coimmunoprecipitation)
# 17302  psi-mi:"MI:0006"(anti bait coimmunoprecipitation)
# 17303  psi-mi:"MI:0006"(anti bait coimmunoprecipitation)
#
#       Publication 1st author(s)          Publication Identifier(s)  \
# 0           Zhang et al. (1999)   mint:MINT-6548485|pubmed:9892668
# 1           Zhang et al. (1999)   mint:MINT-6548485|pubmed:9892668
# 2           Trott et al. (2001)  pubmed:11208814|mint:MINT-5213561
# 3           Horng et al. (2001)  pubmed:11606776|mint:MINT-5214706
# 4           Horng et al. (2001)  pubmed:11606776|mint:MINT-5214706
# ...                         ...                                ...
# 17299       Zhang et al. (2016)      imex:IM-27983|pubmed:26711011
# 17300    Connolly et al. (2019)      pubmed:31666534|imex:IM-28727
# 17301    Connolly et al. (2019)      pubmed:31666534|imex:IM-28727
# 17302         Ren et al. (2011)      pubmed:21653638|imex:IM-28847
# 17303         Ren et al. (2011)      pubmed:21653638|imex:IM-28847
#
#                                       Taxid interactor A  ...  \
# 0      taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 1      taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 2      taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 3      taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 4      taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# ...                                                  ...  ...
# 17299  taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 17300  taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 17301  taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 17302  taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
# 17303  taxid:7227(drome)|taxid:7227("Drosophila melan...  ...
#
#                     Checksum(s) interactor A  \
# 0      rogid:oSo29NrCWIeCi2OMusohCk64uiw7227
# 1      rogid:hbMeldNlirFwVr+5QX9bGiPqZ1w7227
# 2      rogid:Ytd8Ad4FJAfx25V7mHNi9e+F0pw7227
# 3      rogid:ylgI2zl+aLG3S8D2ER2DrTRUpI47227
# 4      rogid:6nIbDMNS71rQ+CzvUkspyPjTd707227
# ...                                      ...
# 17299  rogid:th8wG3uNUK/qw4YANIztmirkXIk7227
# 17300  rogid:BFpJ2gdPZ0GIhl4unPwZxUIdAq87227
# 17301  rogid:BFpJ2gdPZ0GIhl4unPwZxUIdAq87227
# 17302  rogid:3NFMvvrfh1WC+s9QwiDW5BCUr5I7227
# 17303  rogid:3NFMvvrfh1WC+s9QwiDW5BCUr5I7227
#
#                     Checksum(s) interactor B  \
# 0      rogid:bO023bTsk72HhqvmgSjLEIotrDw7227
# 1      rogid:bO023bTsk72HhqvmgSjLEIotrDw7227
# 2      rogid:0wrL1LjHFiPEQg3UxDl917ya/qg7227
# 3      rogid:6nIbDMNS71rQ+CzvUkspyPjTd707227
# 4      rogid:ylgI2zl+aLG3S8D2ER2DrTRUpI47227
# ...                                      ...
# 17299  rogid:th8wG3uNUK/qw4YANIztmirkXIk7227
# 17300  rogid:a8qIHNMXIA6UhaQLWTnjsAvW8OY7227
# 17301  rogid:a8qIHNMXIA6UhaQLWTnjsAvW8OY7227
# 17302  rogid:tH4ckPOwO4Icr1YsnJ1Ck/6Cgmo9606
# 17303  rogid:tH4ckPOwO4Icr1YsnJ1Ck/6Cgmo9606
#
#                                  Interaction Checksum(s) Negative  \
# 0      intact-crc:43555B21FFEEAE7A|rigid:FHdrglr3JteK...    False
# 1      intact-crc:E548EEFF3BEC0246|rigid:6SxefJVI+l+g...    False
# 2      intact-crc:828483A1856961E2|rigid:jm4iqqbCe8IB...    False
# 3      intact-crc:54B41399B32F5A39|rigid:AKh/WPe9ypB1...    False
# 4      intact-crc:6E86439FE2A24F50|rigid:AKh/WPe9ypB1...    False
# ...                                                  ...      ...
# 17299                  rigid:tdk+9Bw26jDxwVSg5hoPlRe1wEg    False
# 17300                  rigid:bsnEpM+NY+vavmTaBfMSTMD6HGc    False
# 17301                  rigid:bsnEpM+NY+vavmTaBfMSTMD6HGc    False
# 17302                  rigid:VDI7YHG9FOw0NVWIEwaX1gCAINY    False
# 17303                  rigid:VDI7YHG9FOw0NVWIEwaX1gCAINY    False
#
#                                  Feature(s) interactor A  \
# 0                       glutathione s tranferase tag:?-?
# 1                       glutathione s tranferase tag:?-?
# 2                                                      -
# 3      v5 tag:?-?|binding-associated region:176-537(I...
# 4                                                      -
# ...                                                  ...
# 17299                                         v5 tag:c-c
# 17300                                        myc tag:?-?
# 17301                                        myc tag:?-?
# 17302                                                  -
# 17303                                                  -
#
#                                  Feature(s) interactor B  \
# 0      binding-associated region:334-337(MINT-1542898...
# 1      35s radiolabel:?-?|binding-associated region:3...
# 2                                                      -
# 3                                                      -
# 4             v5 tag:?-?|binding-associated region:1-237
# ...                                                  ...
# 17299                                         ha tag:?-?
# 17300                                       flag tag:?-?
# 17301                                       flag tag:?-?
# 17302                             mutation:58..58-95..95
# 17303  mutation increasing interaction:58..58-95..95|...
#
#       Stoichiometry(s) interactor A Stoichiometry(s) interactor B  \
# 0                                 -                             -
# 1                                 -                             -
# 2                                 -                             -
# 3                                 -                             -
# 4                                 -                             -
# ...                             ...                           ...
# 17299                             -                             -
# 17300                             -                             -
# 17301                             -                             -
# 17302                             -                             -
# 17303                             -                             -
#
#                      Identification method participant A  \
# 0      psi-mi:"MI:0821"(molecular weight estimation b...
# 1      psi-mi:"MI:0821"(molecular weight estimation b...
# 2            psi-mi:"MI:0396"(predetermined participant)
# 3                         psi-mi:"MI:0113"(western blot)
# 4                         psi-mi:"MI:0113"(western blot)
# ...                                                  ...
# 17299            psi-mi:"MI:0705"(anti tag western blot)
# 17300            psi-mi:"MI:0705"(anti tag western blot)
# 17301            psi-mi:"MI:0705"(anti tag western blot)
# 17302                     psi-mi:"MI:0113"(western blot)
# 17303                     psi-mi:"MI:0113"(western blot)
#
#                      Identification method participant B
# 0      psi-mi:"MI:0821"(molecular weight estimation b...
# 1      psi-mi:"MI:0821"(molecular weight estimation b...
# 2            psi-mi:"MI:0396"(predetermined participant)
# 3                         psi-mi:"MI:0113"(western blot)
# 4                         psi-mi:"MI:0113"(western blot)
# ...                                                  ...
# 17299            psi-mi:"MI:0705"(anti tag western blot)
# 17300            psi-mi:"MI:0705"(anti tag western blot)
# 17301            psi-mi:"MI:0705"(anti tag western blot)
# 17302                     psi-mi:"MI:0113"(western blot)
# 17303                     psi-mi:"MI:0113"(western blot)
#
# [17304 rows x 42 columns]

# %%
dfy2h.to_csv("../data/networks/fly/fly-y2h.tsv", sep = "\t", index = None)
dfcoip.to_csv("../data/networks/fly/fly-coip.tsv", sep = "\t", index = None)

# %% [markdown]
# ## Get the UNIPROT fasta file

# %%
records = list(SeqIO.parse("../data/networks/fly/uniprot-compressed_true_download_true_format_fasta_query__28proteome-2022.09.25-17.08.15.20.fasta", "fasta"))

# %%
filtered_records = [rec for rec in records if len(rec) <= 800]

# %%
len(filtered_records)
# Out:
# 16545

# %% [markdown]
# ## Parse all the proteins in both coip and y2h

# %%
y2hnodes  = set(dfy2h.iloc[:, [0]].values[:, 0]).union(set(dfy2h.iloc[:, [1]].values[:, 0]))
coipnodes = set(dfcoip.iloc[:, [0]].values[:, 0]).union(set(dfcoip.iloc[:, [1]].values[:, 0]))

# %%
allnodes = y2hnodes.union(coipnodes)
allnodes = {a.split(":")[1] for a in allnodes}

# %%
filtnodes = [f.id for f in filtered_records]
filtnodes = [f.split("|")[1] for f in filtnodes]

# %%
frecords = []
for fname, record in zip(filtnodes, filtered_records):
    if fname in allnodes:
        record.id = fname
        frecords.append(record)

# %%
with open("../data/networks/fly/uprotfly.fasta", "w") as output_handle:
    SeqIO.write(frecords, output_handle, "fasta")
len(frecords)
# Out:
# 7975

# %%
import json
finalnodes = {rec.id: i for i, rec in enumerate(frecords)}
with open("../data/networks/fly/all_nodes.json", "w") as an:
    json.dump(finalnodes, an)

# %% [markdown]
# ## Clean up the CoIP and Y2H networks

# %%
dfc = pd.read_csv("../data/networks/fly/fly-coip.tsv", sep = "\t")
dfy = pd.read_csv("../data/networks/fly/fly-y2h.tsv", sep = "\t")

# %%
dfc.shape, dfy.shape
# Out:
# ((17304, 42), (19116, 42))

# %%
dfc1 = dfc.iloc[:, [0, 1]]
dfy1 = dfy.iloc[:, [0, 1]]
dfc1.columns = [0, 1]
dfy1.columns = [0, 1]
dfc1
# Out:
#                       0                 1
# 0      uniprotkb:P16371  uniprotkb:P14003
# 1      uniprotkb:O46036  uniprotkb:P14003
# 2      uniprotkb:P13098  uniprotkb:P08181
# 3      uniprotkb:Q7K105  uniprotkb:P08953
# 4      uniprotkb:P08953  uniprotkb:Q7K105
# ...                 ...               ...
# 17299  uniprotkb:Q9VKD7  uniprotkb:Q9VKD7
# 17300  uniprotkb:Q9VS51  uniprotkb:Q9VND8
# 17301  uniprotkb:Q9VS51  uniprotkb:Q9VND8
# 17302  uniprotkb:P28159  uniprotkb:P20226
# 17303  uniprotkb:P28159  uniprotkb:P20226
#
# [17304 rows x 2 columns]

# %%
dfcnodes = set(dfc1[0]).union(set(dfc1[1]))
dfynodes = set(dfy1[0]).union(set(dfy1[1]))

# %%
dfcmap = {k: k.split(":")[1] for k in dfcnodes}
dfymap = {k: k.split(":")[1] for k in dfynodes}

# %%
dfc2 = dfc1.replace({0:dfcmap, 1:dfcmap})
dfy2 = dfy1.replace({0:dfymap, 1:dfymap})

# %%
dfc2
# Out:
#             0       1
# 0      P16371  P14003
# 1      O46036  P14003
# 2      P13098  P08181
# 3      Q7K105  P08953
# 4      P08953  Q7K105
# ...       ...     ...
# 17299  Q9VKD7  Q9VKD7
# 17300  Q9VS51  Q9VND8
# 17301  Q9VS51  Q9VND8
# 17302  P28159  P20226
# 17303  P28159  P20226
#
# [17304 rows x 2 columns]

# %%
dfy2
# Out:
#             0       1
# 0      P08181  P13097
# 1      P13098  P08181
# 2      Q24159  P23573
# 3      P23572  P54733
# 4      P23573  P91654
# ...       ...     ...
# 19111  B7FNM4  Q8IMF1
# 19112  Q9W1Z1  Q9VV10
# 19113  Q9W1Z1  M9PEI0
# 19114  B7FNN9  Q8IMF1
# 19115  Q9W1Z1  Q9W4Z4
#
# [19116 rows x 2 columns]

# %%
allowednodes = set(finalnodes.keys())
len(allowednodes), list(allowednodes)[:100]
# Out:
# (7975,
#  ['Q9VBT4',
#   'P40794',
#   'Q9VCE0',
#   'Q7JW01',
#   'Q9VLJ5',
#   'Q9VMM6',
#   'Q7K2J4',
#   'Q9VGV9',
#   'Q9XTP7',
#   'Q9VC81',
#   'Q9W2M2',
#   'Q9VWY6',
#   'Q9W528',
#   'Q9VHG6',
#   'Q9W021',
#   'Q9VI14',
#   'Q8MSY4',
#   'A1ZAC4',
#   'Q9VL14',
#   'P38979',
#   'O18399',
#   'Q9VL44',
#   'Q9VAF9',
#   'Q9W4D8',
#   'Q9VFN3',
#   'Q8IH24',
#   'C7LAF3',
#   'Q9VHR7',
#   'O16130',
#   'Q7K4L8',
#   'Q8IRU1',
#   'Q8WTI6',
#   'Q8IQG3',
#   'Q9W5B3',
#   'Q9VXR5',
#   'Q0E9B6',
#   'A0A0B4KEQ5',
#   'Q9VG98',
#   'Q95TS8',
#   'Q7K284',
#   'Q9VRZ3',
#   'Q8IGP1',
#   'E2QCZ5',
#   'Q9VBR1',
#   'Q9VTY0',
#   'Q9VUB0',
#   'Q9VJ90',
#   'Q9V557',
#   'Q9W3T2',
#   'Q8T452',
#   'Q9VU69',
#   'Q7JY31',
#   'F0JAI6',
#   'Q94918',
#   'Q8IN08',
#   'Q1LZ24',
#   'Q95U38',
#   'Q9VG01',
#   'Q9VGB2',
#   'Q9VVP3',
#   'Q7JZ51',
#   'Q9VAL7',
#   'Q7JRC3',
#   'Q9VID7',
#   'Q2MGL3',
#   'Q9VX14',
#   'O77460',
#   'Q9VHI4',
#   'Q9VGY8',
#   'Q9VC65',
#   'Q9VCY7',
#   'Q9VPF3',
#   'Q8T8W0',
#   'Q9W1I8',
#   'Q6IKG0',
#   'Q9VIK5',
#   'P06754',
#   'Q8IR18',
#   'Q9VFT4',
#   'Q9VCU4',
#   'Q9I7U1',
#   'Q9VW78',
#   'Q8SZ15',
#   'Q95RJ9',
#   'Q9VA10',
#   'Q9VX51',
#   'Q8IG84',
#   'P07140',
#   'Q9VLC5',
#   'O02649',
#   'Q9VG74',
#   'Q9W4Q7',
#   'Q9V9T0',
#   'Q86BI9',
#   'A1Z7U5',
#   'Q9VCY2',
#   'Q9VAC7',
#   'P58952',
#   'Q9VE97',
#   'Q9VUU3'])

# %%
dfc3 = dfc2[(dfc2[0].isin(allowednodes)) & (dfc2[1].isin(allowednodes))]
dfc3
# Out:
#             0       1
# 0      P16371  P14003
# 1      O46036  P14003
# 2      P13098  P08181
# 5      Q7K105  Q9V3B4
# 6      Q7K105  Q8IRY7
# ...       ...     ...
# 17297  Q9W3F7  Q9VKD7
# 17298  Q9W3F7  Q9VKD7
# 17299  Q9VKD7  Q9VKD7
# 17300  Q9VS51  Q9VND8
# 17301  Q9VS51  Q9VND8
#
# [4372 rows x 2 columns]

# %%
dfy3 = dfy2[(dfy2[0].isin(allowednodes)) & (dfy2[1].isin(allowednodes))]
dfy3
# Out:
#             0       1
# 0      P08181  P13097
# 1      P13098  P08181
# 3      P23572  P54733
# 12     Q9VI13  P40792
# 13     Q9VI13  P48554
# ...       ...     ...
# 19108  Q9VEK1  Q9W1Z1
# 19109  Q9VH59  Q9W1Z1
# 19112  Q9W1Z1  Q9VV10
# 19113  Q9W1Z1  M9PEI0
# 19115  Q9W1Z1  Q9W4Z4
#
# [13162 rows x 2 columns]

# %%
dfy3.to_csv("../data/networks/fly/fly-y2h-filtered.tsv", sep = "\t", header = None, index = None)
dfc3.to_csv("../data/networks/fly/fly-coip-filtered.tsv", sep = "\t", header = None, index = None)

# %% [markdown]
# ## Filter the fasta file again

# %%
from Bio import SeqIO
records = list(SeqIO.parse("../data/networks/fly/uprotfly.fasta", "fasta"))

# %%
allnodes = set(dfy3[0]).union(set(dfy3[1])).union(set(dfc3[0])).union(set(dfc3[1]))

# %%
len(allnodes)
# Out:
# 4229

# %%
records = [r for r in records if (r.id in allnodes)]

# %%
len(records)
# Out:
# 4229

# %%
with open("../data/networks/fly/uprotfly-final.fasta", "w") as output_handle:
    SeqIO.write(records, output_handle, "fasta")

# %% [markdown]
# ## Compute the D-SCRIPT embedding

# %%
# !gpustat
# Out:
# imp                      Sun Sep 25 17:42:46 2022  470.141.03
# [0] Tesla V100-PCIE-32GB | 32'C,   0 % |     0 / 32510 MB |
# [1] Tesla V100-PCIE-32GB | 30'C,   0 % |     0 / 32510 MB |
# [2] Tesla V100-PCIE-32GB | 32'C,   0 % |     0 / 32510 MB |
# [3] Tesla V100-PCIE-32GB | 32'C,   0 % |     0 / 32510 MB |
# [4] Tesla V100-PCIE-32GB | 31'C,   0 % |     0 / 32510 MB |
# [5] Tesla V100-PCIE-32GB | 32'C,   0 % |     0 / 32510 MB |
# [6] Tesla V100-PCIE-32GB | 31'C,   0 % |     0 / 32510 MB |
# [7] Tesla V100-PCIE-32GB | 31'C,   3 % |     0 / 32510 MB |

# %%
# !dscript embed --help
# Out:
# usage: dscript embed [-h] --seqs SEQS -o OUTFILE [-d DEVICE]
#
# Generate new embeddings using pre-trained language model.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --seqs SEQS           Sequences to be embedded
#   -o OUTFILE, --outfile OUTFILE
#                         h5 file to write results
#   -d DEVICE, --device DEVICE
#                         Compute device to use

# %%
# !dscript embed --seqs ../data/networks/fly/uprotfly-final.fasta -o ../data/networks/fly/uprotfly-final.h5 -d 0
# Out:
# [2022-09-25-17:43:57] # Using CUDA device 0 - Tesla V100-PCIE-32GB
# [2022-09-25-17:43:57] # Loading Model...
# [2022-09-25-17:43:57] Downloading model lm_v1 from http://cb.csail.mit.edu/cb/dscript/data/models/dscript_lm_v1.pt...
# [2022-09-25-17:44:02] # Loading Sequences...
# 100%|████████████████████████████████████| 4229/4229 [00:00<00:00, 51142.53it/s]
# [2022-09-25-17:44:02] # 4229 Sequences Loaded
# [2022-09-25-17:44:02] # Approximate Storage Required (varies by average sequence length): ~33.832GB
# [2022-09-25-17:44:02] # Storing to ../data/networks/fly/uprotfly-final.h5...
# 100%|███████████████████████████████████████| 4229/4229 [09:22<00:00,  7.52it/s]

# %% [markdown]
# ## Generate the training and test cases for the networks

# %%
import numpy as np

def get_test_set(net, neg_to_pos_ratio = 10):
    if isinstance(net, str):
        df = pd.read_csv(netfile, sep = "\t", header = None)
    else:
        df = net
    
    df.loc[df[0] > df[1]] = df.loc[df[0] > df[1], [1, 0]]
    df[2] = 1
    
    edges = {}
    for p, q, w in df.values:
        edges[f"{p}:{q}"] = w
    
    
    nodes  = list(set(df[0]).union(set(df[1])))
    n_nodes= len(nodes)
    
    noneg  = neg_to_pos_ratio * len(df)
    
    negset = []
    while len(negset) < noneg:
        p, q = np.random.randint(n_nodes, size=2)
        if p == q:
            continue
        p_, q_ = [nodes[p], nodes[q]]
        if p_ > q_:
            temp = p_
            p_   = q_
            q_   = temp
        if f"{p}:{q}" in edges:
            continue
        negset.append((p_, q_, 0))
    dfneg = pd.DataFrame(negset, columns = [0, 1, 2])
    return pd.concat([df, dfneg])

# %%
tset = get_test_set("../data/networks/fly/fly-coip-filtered.tsv", neg_to_pos_ratio=10)
tset.to_csv("../data/networks/fly/fly_coip_evaluation.tsv", sep = "\t", header = None, index = None)

# %%
dfy  = pd.read_csv("../data/networks/fly/fly-y2h-filtered.tsv", sep = "\t", header = None)
dfy1 = dfy.sample(n=4371, random_state=  1)
# Out:
# True
